# %%
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout

import ROOT as rt
import uproot
#from root_numpy import root2array, tree2array
#from root_pandas import read_root
import h5py 

from sklearn.preprocessing import LabelEncoder
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import keras.backend as K
from keras.metrics import SparseCategoricalAccuracy
from keras.losses import SparseCategoricalCrossentropy

from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args

from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

import numpy as np
import numpy.lib.recfunctions as nlr
import pandas as pd
import os, sys
from matplotlib import pyplot as plt
import math
try:
    import setGPU
except:
    os.environ['KERAS_BACKEND'] = 'tensorflow'
    os.environ['CUDA_VISIBLE_DEVICES'] = '5'

import gpustat
gpustat.print_gpustat()
os.environ['CUDA_VISIBLE_DEVICES']='3'
# Out:
# Welcome to JupyROOT 6.22/02
# setGPU: Setting GPU to: 0
# gpu-ibanks-3.hep.caltech.edu  Thu Aug 26 19:29:38 2021  470.57.02
# [0] NVIDIA GeForce GTX 1080 | 22'C,   0 % |     1 /  8119 MB |
# [1] NVIDIA GeForce GTX 1080 | 24'C,   0 % |     1 /  8119 MB |
# [2] NVIDIA GeForce GTX 1080 | 25'C,   0 % |     1 /  8119 MB |
# [3] NVIDIA GeForce GTX 1080 | 22'C,   0 % |     1 /  8119 MB |
# [4] NVIDIA GeForce GTX 1080 | 25'C,   0 % |     1 /  8119 MB |
# [5] NVIDIA GeForce GTX 1080 | 25'C,   0 % |   727 /  8119 MB | 3012(723M)
# [6] NVIDIA GeForce GTX 1080 | 25'C,   0 % |     1 /  8119 MB |
# [7] NVIDIA GeForce GTX 1080 | 27'C,   0 % |     1 /  8119 MB |

# %% [markdown]
# ### Load MC samples

# %%
def samp_to_df(samp_name, total_num):
    dfs = []
    tree_vars = [b'leading_photon_pt', b'subleading_photon_pt', b'diphoton_pt', b'diphoton_mass',
           b'leading_bjet_pt', b'subleading_bjet_pt', b'dibjet_pt', b'dibjet_mass',
           b'leading_bjet_pt_corr', b'subleading_bjet_pt_corr', b'dibjet_pt_corr', b'dibjet_mass_corr',
           b'leading_pho_pt_over_dimass', b'leading_bjet_pt_over_dimass', b'leading_bjet_pt_over_dimass_corr',
           b'subleading_pho_pt_over_dimass', b'subleading_bjet_pt_over_dimass', b'subleading_bjet_pt_over_dimass_corr',
           b'leading_photon_phi', b'leading_photon_eta', b'subleading_photon_phi', b'subleading_photon_eta',
           b'diphoton_eta', b'photon_delR', b'diphoton_pt_over_diphoton_mass',
           b'leading_bjet_phi', b'leading_bjet_eta', b'subleading_bjet_phi', b'subleading_bjet_eta',
           b'dibjet_eta', b'bjet_delR', b'dibjet_pt_over_dibjet_mass', b'dibjet_pt_over_dibjet_mass_corr',
           b'leadingDeepBscore', b'subleadingDeepBscore', b'sumDeepBscore',
           b'rec_pho_bjet_min_dR', b'all_pho_bjet_min_dR', b'dphi_met_leading_bjet', b'dphi_met_subleading_bjet',
           b'leading_vbfjet_pt', b'subleading_vbfjet_pt', b'divbfjet_pt', b'divbfjet_mass',
           b'leading_vbfjet_phi', b'leading_vbfjet_eta', b'subleading_vbfjet_phi', b'subleading_vbfjet_eta',
           b'leading_vbfjet_pt_over_dimass', b'subleading_vbfjet_pt_over_dimass', b'divbfjet_pt_over_dimass',
           b'divbfjet_eta', b'vbfjet_delR', b'vbfjet_del_eta',
           b'MET_pt', b'MET_phi', b'MET_sumEt',
           b'recon', b'ggHH_recon', b'VBFHH_recon', b'genweight', b'nbjet', b'nvbfjet', b'nphoton', b'njet',
           b'run', b'lumi', b'event']
    for i in range(total_num+1):
        file_name = f'/storage/af/user/schen7/CMSSW_9_4_2/src/Higgs/HHbbgg/HHbbggAna/condor/output/{samp_name}{i}.root'
        samp_file = uproot.open(file_name)
        samp_array = samp_file['tree'].arrays(tree_vars)
        samp_df = pd.DataFrame(samp_array)
        dfs.append(samp_df)
    combine_df = pd.concat(dfs)
    return combine_df

# %%
# Set up dataframes - 2018 

# Signals
GluGluToHH_df_2018 = samp_to_df('job_2_ntuple20180819v1/GluGluToHHTo2B2G_node_cHHH1_TuneCP5_PSWeights_13TeV-powheg-pythia8Job2ifile', 0)
VBFHH_df_2018= samp_to_df('job_3_ntuple20180819v1/VBFHHTo2B2G_CV_1_C2V_1_C3_1_TuneCP5_PSWeights_13TeV-madgraph-pythia8Job3ifile', 0)

# Backgrounds
VHToGG_df_2018 = samp_to_df('job_4_ntuple20180819v1/VHToGG_M125_13TeV_amcatnloFXFX_madspin_pythia8Job4ifile', 0)
ttHToGG_df_2018 = samp_to_df('job_5_ntuple20180819v1/ttHToGG_M125_TuneCP5_PSweights_13TeV-powheg-pythia8Job5ifile', 0)
VBFHToGG_df_2018 = samp_to_df('job_6_ntuple20180819v1/VBFHToGG_M125_13TeV_amcatnlo_pythia8Job6ifile', 0)
GluGluHToGG_df_2018 = samp_to_df('job_7_ntuple20180819v1/GluGluHToGG_M125_TuneCP5_13TeV-amcatnloFXFX-pythia8Job7ifile', 0)
TTJets_df_2018 = samp_to_df('job_8_ntuple20180819v1/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8Job8ifile', 60)
TTGJets_df_2018 = samp_to_df('job_9_ntuple20180819v1/TTGJets_TuneCP5_13TeV-amcatnloFXFX-madspin-pythia8Job9ifile', 3)
TTGG_0Jets_df_2018 = samp_to_df('job_10_ntuple20180819v1/TTGG_0Jets_TuneCP5_13TeV_amcatnlo_madspin_pythia8Job10ifile', 5)
GJet_SmallPt_df_2018 = samp_to_df('job_11_ntuple20180819v1/GJet_Pt-20to40_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8Job11ifile', 3)
GJet_BigPt_df_2018 = samp_to_df('job_12_ntuple20180819v1/GJet_Pt-40toInf_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8Job12ifile', 2)
DiPhotonJetsBox_df_2018 = samp_to_df('job_13_ntuple20180819v1/DiPhotonJetsBox_MGG-80toInf_13TeV-SherpaJob13ifile', 4)
DiPhotonJetsBox1B_df_2018 = samp_to_df('job_14_ntuple20180819v1/DiPhotonJetsBox1BJet_MGG-80toInf_13TeV-SherpaJob14ifile', 0)
DiPhotonJetsBox2B_df_2018 = samp_to_df('job_15_ntuple20180819v1/DiPhotonJetsBox2BJets_MGG-80toInf_13TeV-SherpaJob15ifile', 0)
QCD_Jets_df_2018 = samp_to_df('job_16_ntuple20180819v1/QCD_Pt-40toInf_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8Job16ifile', 15)

# Set up dataframes - 2017

# Signals
GluGluToHH_df_2017 = samp_to_df('job_2_ntuple20170819v1/GluGluToHHTo2B2G_node_cHHH1_TuneCP5_PSWeights_13TeV-powheg-pythia8Job2ifile', 3)
VBFHH_df_2017 = samp_to_df('job_3_ntuple20170819v1/VBFHHTo2B2G_CV_1_C2V_1_C3_1_13TeV-madgraphJob3ifile', 1)

# Backgrounds
VHToGG_df_2017 = samp_to_df('job_4_ntuple20170819v1/VHToGG_M125_13TeV_amcatnloFXFX_madspin_pythia8Job4ifile', 0)
ttHToGG_df_2017 = samp_to_df('job_5_ntuple20170819v1/ttHToGG_M125_13TeV_powheg_pythia8Job5ifile', 0)
VBFHToGG_df_2017 = samp_to_df('job_6_ntuple20170819v1/VBFHToGG_M-125_13TeV_powheg_pythia8Job6ifile', 2)
GluGluHToGG_df_2017 = samp_to_df('job_7_ntuple20170819v1/GluGluHToGG_M-125_13TeV_powheg_pythia8Job7ifile', 0)
TTJets_df_2017 = samp_to_df('job_8_ntuple20170819v1/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8Job8ifile', 38)
TTGJets_df_2017 = samp_to_df('job_9_ntuple20170819v1/TTGJets_TuneCP5_13TeV-amcatnloFXFX-madspin-pythia8Job9ifile', 10)
TTGG_0Jets_df_2017 = samp_to_df('job_10_ntuple20170819v1/TTGG_0Jets_TuneCP5_13TeV_amcatnlo_madspin_pythia8Job10ifile', 1)
GJet_SmallPt_df_2017 = samp_to_df('job_11_ntuple20170819v1/GJet_Pt-20to40_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8Job11ifile', 2)
GJet_BigPt_df_2017 = samp_to_df('job_12_ntuple20170819v1/GJet_Pt-40toInf_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8Job12ifile', 20)
DiPhotonJetsBox_df_2017 = samp_to_df('job_1_ntuple20170819v2/DiPhotonJetsBox_MGG-80toInf_13TeV-SherpaJob1ifile', 16)
DiPhotonJetsBox1B_df_2017 = samp_to_df('job_14_ntuple20170819v1/DiPhotonJetsBox1BJet_MGG-80toInf_13TeV-SherpaJob14ifile', 3)
DiPhotonJetsBox2B_df_2017 = samp_to_df('job_15_ntuple20170819v1/DiPhotonJetsBox2BJets_MGG-80toInf_13TeV-SherpaJob15ifile', 5)
QCD_Jets_df_2017 = samp_to_df('job_16_ntuple20170819v1/QCD_Pt-40toInf_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8Job16ifile', 3)

# Set up dataframes - 2016 

# Signals
GluGluToHH_df_2016 = samp_to_df('job_2_ntuple20160819v1/GluGluToHHTo2B2G_node_cHHH1_TuneCUETP8M1_PSWeights_13TeV-powheg-pythia8Job2ifile', 0)
VBFHH_df_2016 = samp_to_df('job_3_ntuple20160819v1/VBFHHTo2B2G_CV_1_C2V_1_C3_1_13TeV-madgraphJob3ifile', 0)

# Background
VHToGG_df_2016 = samp_to_df('job_4_ntuple20160819v1/VHToGG_M125_13TeV_amcatnloFXFX_madspin_pythia8Job4ifile', 0)
ttHToGG_df_2016 = samp_to_df('job_5_ntuple20160819v1/ttHToGG_M125_13TeV_powheg_pythia8_v2Job5ifile', 0)
VBFHToGG_df_2016 = samp_to_df('job_6_ntuple20160819v1/VBFHToGG_M125_13TeV_amcatnlo_pythia8_v2Job6ifile', 2)
GluGluHToGG_df_2016 = samp_to_df('job_7_ntuple20160819v1/GluGluHToGG_M125_13TeV_amcatnloFXFX_pythiaJob7ifile', 0)
TTJets_df_2016 = samp_to_df('job_8_ntuple20160819v1/TTJets_TuneCUETP8M2T4_13TeV-amcatnloFXFX-pythia8Job8ifile', 8)
TTGJets_df_2016 = samp_to_df('job_9_ntuple20160819v1/TTGJets_TuneCUETP8M1_13TeV-amcatnloFXFX-madspin-pythia8Job9ifile', 2)
TTGG_0Jets_df_2016 = samp_to_df('job_10_ntuple20160819v1/TTGG_0Jets_TuneCUETP8M1_13TeV_amcatnlo_madspin_pythia8Job10ifile', 0)
GJet_SmallPt_df_2016 = samp_to_df('job_11_ntuple20160819v1/GJet_Pt-20to40_DoubleEMEnriched_MGG-80toInf_TuneCUETP8M1_13TeV_Pythia8Job11ifile', 2)
GJet_BigPt_df_2016 = samp_to_df('job_12_ntuple20160819v1/GJet_Pt-40toInf_DoubleEMEnriched_MGG-80toInf_TuneCUETP8M1_13TeV_Pythia8Job12ifile', 12)
DiPhotonJetsBox_df_2016 = samp_to_df('job_13_ntuple20160819v1/DiPhotonJetsBox_MGG-80toInf_13TeV-SherpaJob13ifile', 9)
DiPhotonJetsBox1B_df_2016 = samp_to_df('job_14_ntuple20160819v1/DiPhotonJetsBox1BJet_MGG-80toInf_TuneSherpa_13TeV-SherpaJob14ifile', 3)
DiPhotonJetsBox2B_df_2016 = samp_to_df('job_15_ntuple20160819v1/DiPhotonJetsBox2BJets_MGG-80toInf_TuneSherpa_13TeV-SherpaJob15ifile', 4)
QCD_Jets_df_2016 = samp_to_df('job_16_ntuple20160819v1/QCD_Pt-40toInf_DoubleEMEnriched_MGG-80toInf_TuneCUETP8M1_13TeV_Pythia8Job16ifile', 3)

# Combine by sample (recon == 1; photon cut == 90)

# Signals 
GluGluToHH_df = pd.concat([GluGluToHH_df_2018, GluGluToHH_df_2017, GluGluToHH_df_2016], ignore_index=True)
VBFHH_df = pd.concat([VBFHH_df_2018, VBFHH_df_2017, VBFHH_df_2016], ignore_index=True)

# Backgrounds
VHToGG_df = pd.concat([VHToGG_df_2018, VHToGG_df_2017, VHToGG_df_2016], ignore_index=True)
ttHToGG_df = pd.concat([ttHToGG_df_2018, ttHToGG_df_2017, ttHToGG_df_2016], ignore_index=True)
VBFHToGG_df = pd.concat([VBFHToGG_df_2018, VBFHToGG_df_2017, VBFHToGG_df_2016], ignore_index=True)
GluGluHToGG_df = pd.concat([GluGluHToGG_df_2018, GluGluHToGG_df_2017, GluGluHToGG_df_2016], ignore_index=True)
TTJets_df= pd.concat([TTJets_df_2018, TTJets_df_2017, TTJets_df_2016], ignore_index=True)
TTGJets_df = pd.concat([TTGJets_df_2018, TTGJets_df_2017, TTGJets_df_2016], ignore_index=True)
TTGG_0Jets_df = pd.concat([TTGG_0Jets_df_2018, TTGG_0Jets_df_2017, TTGG_0Jets_df_2016], ignore_index=True)
GJet_SmallPt_df = pd.concat([GJet_SmallPt_df_2018, GJet_SmallPt_df_2017, GJet_SmallPt_df_2016], ignore_index=True)
GJet_BigPt_df = pd.concat([GJet_BigPt_df_2018, GJet_BigPt_df_2017, GJet_BigPt_df_2016], ignore_index=True)
DiPhotonJetsBox_df = pd.concat([DiPhotonJetsBox_df_2018, DiPhotonJetsBox_df_2017, DiPhotonJetsBox_df_2016], ignore_index=True)
DiPhotonJetsBox1B_df = pd.concat([DiPhotonJetsBox1B_df_2018, DiPhotonJetsBox1B_df_2017, DiPhotonJetsBox1B_df_2016], ignore_index=True)
DiPhotonJetsBox2B_df = pd.concat([DiPhotonJetsBox2B_df_2018, DiPhotonJetsBox2B_df_2017, DiPhotonJetsBox2B_df_2016], ignore_index=True)
QCD_Jets_df = pd.concat([QCD_Jets_df_2018, QCD_Jets_df_2017, QCD_Jets_df_2016], ignore_index=True)

# %%
# Select ggHH signal specifically -- pho == 90

dfs_combine = [GluGluToHH_df, VBFHH_df,
               VHToGG_df, ttHToGG_df, VBFHToGG_df, GluGluHToGG_df, 
                TTJets_df, TTGJets_df, TTGG_0Jets_df, 
            GJet_SmallPt_df, GJet_BigPt_df,
             DiPhotonJetsBox_df, DiPhotonJetsBox1B_df, DiPhotonJetsBox2B_df, QCD_Jets_df]

dfs_ggHH = []

for i in range(len(dfs_combine)):
    if i == 11: # downsize DiPhotonJetsBox
        df_ggHH = dfs_combine[i][dfs_combine[i][b'ggHH_recon'] == 1]
        df_ggHH_shuff = df_ggHH.sample(frac=1).reset_index(drop=True)
        df_ggHH_short = df_ggHH_shuff.truncate(after = 197069)
        df_total_weight = np.sum(df_ggHH.loc[:, b'genweight'].values)
        df_short_weight = np.sum(df_ggHH_short.loc[:, b'genweight'].values)
        df_ggHH_short[b'genweight'] = df_ggHH_short.loc[:, b'genweight'].values * df_total_weight / df_short_weight
        dfs_ggHH.append(df_ggHH_short)
    else:
        df_ggHH = dfs_combine[i][dfs_combine[i][b'ggHH_recon'] == 1]
        dfs_ggHH.append(df_ggHH)

# %% [markdown]
# ## Preprocessing

# %%
mc_labels = ['GluGluToHH', 'VBFToHH',
            'VHToGG', 'ttHToGG', 'VBFHToGG', 'GluGluHtoGG',
            'TTJets', 'TTGJets', 'TTGG_0Jets',
            'GJet_SmallPt', 'GJet_BigPt', 'DiPhotonJetsBox', 'DiPhotonJetsBox1B', 'DiPhotonJetsBox2B', 'QCDJets']

dfs_ggHH_label = []
total = 0
for i in range(len(mc_labels)):
    df = pd.DataFrame()
    for column in list(dfs_ggHH[i].columns):
        df[column] = dfs_ggHH[i].loc[:, column].values
    samp_label = [mc_labels[i]] * len(dfs_ggHH[i].index)
    df[b'label'] = samp_label
    print(mc_labels[i])
    print(len(dfs_ggHH[i].index))
    total += len(dfs_ggHH[i].index)
    samp_label_num = [i] * len(dfs_ggHH[i].index)
    df[b'label_num'] = samp_label_num
    dfs_ggHH_label.append(df)

full_df = pd.concat(dfs_ggHH_label, ignore_index=True)
print(total)
print(len(full_df.index))
print(full_df[b'label'].value_counts())
full_df.head()
# Out:
# GluGluToHH
# 115095
# VBFToHH
# 123786
# VHToGG
# 150739
# ttHToGG
# 128314
# VBFHToGG
# 117796
# GluGluHtoGG
# 131781
# TTJets
# 233707
# TTGJets
# 80870
# TTGG_0Jets
# 45301
# GJet_SmallPt
# 2565
# GJet_BigPt
# 78388
# DiPhotonJetsBox
# 197070
# DiPhotonJetsBox1B
# 79813
# DiPhotonJetsBox2B
# 43283
# QCDJets
# 414
# 1528922
# 1528922
# TTJets               233707
# DiPhotonJetsBox      197070
# VHToGG               150739
# GluGluHtoGG          131781
# ttHToGG              128314
# VBFToHH              123786
# VBFHToGG             117796
# GluGluToHH           115095
# TTGJets               80870
# DiPhotonJetsBox1B     79813
# GJet_BigPt            78388
# TTGG_0Jets            45301
# DiPhotonJetsBox2B     43283
# GJet_SmallPt           2565
# QCDJets                 414
# Name: b'label', dtype: int64
#    b'leading_photon_pt'  b'subleading_photon_pt'  b'diphoton_pt'  \
# 0             81.548317                68.587204       84.036278
# 1            109.037231                87.997322      153.144653
# 2             99.698898                54.716755       92.352104
# 3             78.673645                74.914726      111.698479
# 4            447.419708               159.403656      594.103027
#
#    b'diphoton_mass'  b'leading_bjet_pt'  b'subleading_bjet_pt'  b'dibjet_pt'  \
# 0        124.439453             80.1250                60.7500     88.046196
# 1        124.160385            115.9375                69.3125    160.948395
# 2        124.160637             92.5625                26.7500    112.699577
# 3        120.000145            178.5000                31.0625    172.392776
# 4        123.621674            485.0000                46.3750    525.561584
#
#    b'dibjet_mass'  b'leading_bjet_pt_corr'  b'subleading_bjet_pt_corr'  ...  \
# 0      111.977684                89.827637                   63.123047  ...
# 1      111.282120               117.749023                   75.133667  ...
# 2      106.316811               100.517090                   32.967285  ...
# 3      125.170486               164.816162                   27.756042  ...
# 4       98.438232               465.817871                   57.153564  ...
#
#    b'genweight'  b'nbjet'  b'nvbfjet'  b'nphoton'  b'njet'  b'run'  b'lumi'  \
# 0     -0.000028         3           0           2        6       1     1121
# 1      0.000028         2           0           2        5       1     1121
# 2      0.000028         2           1           2       10       1     1121
# 3      0.000028         2           0           2       13       1     1121
# 4      0.000028         2           0           2        8       1     1121
#
#    b'event'    b'label'  b'label_num'
# 0    112017  GluGluToHH             0
# 1    112010  GluGluToHH             0
# 2    112001  GluGluToHH             0
# 3    112006  GluGluToHH             0
# 4    112019  GluGluToHH             0
#
# [5 rows x 70 columns]

# %%
# define variables
training_vars = [b'leading_photon_eta', b'leading_photon_phi', 
                b'subleading_photon_eta', b'subleading_photon_phi',
                 b'leading_bjet_pt_corr', b'leading_bjet_eta', b'leading_bjet_phi',
                 b'subleading_bjet_pt_corr', b'subleading_bjet_eta', b'subleading_bjet_phi',
                 b'leadingDeepBscore', b'subleadingDeepBscore', b'sumDeepBscore',
                 b'leading_pho_pt_over_dimass', b'subleading_pho_pt_over_dimass',
                 b'diphoton_pt_over_diphoton_mass', b'dibjet_pt_over_dibjet_mass_corr',
                 b'rec_pho_bjet_min_dR', b'all_pho_bjet_min_dR', b'dphi_met_leading_bjet', b'dphi_met_subleading_bjet',
                 b'MET_pt', b'MET_phi', b'MET_sumEt',
                 b'nbjet', b'nphoton', b'njet'
                ]

aug_vars = [b'dibjet_mass', b'diphoton_mass', b'event']

w_var = [b'genweight']

# select df columns
x_dfs = []


x_df = full_df[training_vars]
x_full_df = full_df[training_vars + aug_vars + w_var]
y_df = full_df[b'label_num']
X = x_df.values
X_weights = full_df[w_var].values
Y = y_df.values

# %%
# split into training and test; following: https://www.kaggle.com/hungdo1291/keras-dnn-multi-class
random_seed=2
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size = 0.2, random_state=random_seed)
X_train_weight, X_val_weight, ph_1, ph_2 = train_test_split(X_weights, Y, test_size = 0.2, random_state=random_seed)

# %% [markdown]
# ## Model Setup

# %%
def multi_DNN(n_hidden = 2, first_neuron = 100, n_neurons = 64, dropout_rate = 0.3, activation_func = 'sigmoid', lr= 0.00002):
    model = Sequential()
    model.add(Dense(first_neuron, input_dim=len(training_vars), activation='relu'))
    model.add(Dropout(dropout_rate))
    for layer in range(n_hidden):
        model.add(Dense(n_neurons, activation = activation_func))
        model.add(Dropout(dropout_rate))
    model.add(Dense(15, activation = 'softmax'))
    opt = Adam(learning_rate = lr)
    model.compile(loss=SparseCategoricalCrossentropy(), optimizer=opt, metrics=[SparseCategoricalAccuracy()])
    return model

# %% [markdown]
# ## Model Test

# %%
model = multi_DNN()
history = model.fit(X_train, Y_train, epochs=1000,batch_size=64, validation_split = 0.2, 
            callbacks=[EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')])
# Out:
# Epoch 1/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.5478 - sparse_categorical_accuracy: 0.1324 - val_loss: 2.4583 - val_sparse_categorical_accuracy: 0.1660
# Epoch 2/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.4779 - sparse_categorical_accuracy: 0.1575 - val_loss: 2.4380 - val_sparse_categorical_accuracy: 0.1934
# Epoch 3/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.4500 - sparse_categorical_accuracy: 0.1761 - val_loss: 2.4079 - val_sparse_categorical_accuracy: 0.1971
# Epoch 4/1000
# 15290/15290 [==============================] - 26s 2ms/step - loss: 2.4167 - sparse_categorical_accuracy: 0.1917 - val_loss: 2.3331 - val_sparse_categorical_accuracy: 0.2194
# Epoch 5/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.3647 - sparse_categorical_accuracy: 0.2060 - val_loss: 2.2760 - val_sparse_categorical_accuracy: 0.2282
# Epoch 6/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.3244 - sparse_categorical_accuracy: 0.2157 - val_loss: 2.2614 - val_sparse_categorical_accuracy: 0.2296
# Epoch 7/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.3006 - sparse_categorical_accuracy: 0.2214 - val_loss: 2.2478 - val_sparse_categorical_accuracy: 0.2312
# Epoch 8/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.2817 - sparse_categorical_accuracy: 0.2251 - val_loss: 2.2321 - val_sparse_categorical_accuracy: 0.2332
# Epoch 9/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.2639 - sparse_categorical_accuracy: 0.2290 - val_loss: 2.2124 - val_sparse_categorical_accuracy: 0.2424
# Epoch 10/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.2420 - sparse_categorical_accuracy: 0.2362 - val_loss: 2.1888 - val_sparse_categorical_accuracy: 0.2536
# Epoch 11/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.2189 - sparse_categorical_accuracy: 0.2442 - val_loss: 2.1610 - val_sparse_categorical_accuracy: 0.2603
# Epoch 12/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.1955 - sparse_categorical_accuracy: 0.2501 - val_loss: 2.1273 - val_sparse_categorical_accuracy: 0.2678
# Epoch 13/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.1622 - sparse_categorical_accuracy: 0.2584 - val_loss: 2.0709 - val_sparse_categorical_accuracy: 0.2818
# Epoch 14/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.1194 - sparse_categorical_accuracy: 0.2680 - val_loss: 2.0179 - val_sparse_categorical_accuracy: 0.2916
# Epoch 15/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.0742 - sparse_categorical_accuracy: 0.2772 - val_loss: 1.9736 - val_sparse_categorical_accuracy: 0.3009
# Epoch 16/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.0382 - sparse_categorical_accuracy: 0.2851 - val_loss: 1.9483 - val_sparse_categorical_accuracy: 0.3063
# Epoch 17/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 2.0109 - sparse_categorical_accuracy: 0.2910 - val_loss: 1.9332 - val_sparse_categorical_accuracy: 0.3094
# Epoch 18/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9932 - sparse_categorical_accuracy: 0.2953 - val_loss: 1.9236 - val_sparse_categorical_accuracy: 0.3120
# Epoch 19/1000
# 15290/15290 [==============================] - 26s 2ms/step - loss: 1.9799 - sparse_categorical_accuracy: 0.2990 - val_loss: 1.9169 - val_sparse_categorical_accuracy: 0.3145
# Epoch 20/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9707 - sparse_categorical_accuracy: 0.3016 - val_loss: 1.9107 - val_sparse_categorical_accuracy: 0.3181
# Epoch 21/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9636 - sparse_categorical_accuracy: 0.3040 - val_loss: 1.9085 - val_sparse_categorical_accuracy: 0.3214
# Epoch 22/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9574 - sparse_categorical_accuracy: 0.3057 - val_loss: 1.9017 - val_sparse_categorical_accuracy: 0.3231
# Epoch 23/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9521 - sparse_categorical_accuracy: 0.3082 - val_loss: 1.8970 - val_sparse_categorical_accuracy: 0.3245
# Epoch 24/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9466 - sparse_categorical_accuracy: 0.3094 - val_loss: 1.8927 - val_sparse_categorical_accuracy: 0.3266
# Epoch 25/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9420 - sparse_categorical_accuracy: 0.3115 - val_loss: 1.8882 - val_sparse_categorical_accuracy: 0.3277
# Epoch 26/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9374 - sparse_categorical_accuracy: 0.3125 - val_loss: 1.8827 - val_sparse_categorical_accuracy: 0.3301
# Epoch 27/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9331 - sparse_categorical_accuracy: 0.3141 - val_loss: 1.8786 - val_sparse_categorical_accuracy: 0.3307
# Epoch 28/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9294 - sparse_categorical_accuracy: 0.3150 - val_loss: 1.8733 - val_sparse_categorical_accuracy: 0.3325
# Epoch 29/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9251 - sparse_categorical_accuracy: 0.3169 - val_loss: 1.8708 - val_sparse_categorical_accuracy: 0.3336
# Epoch 30/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9208 - sparse_categorical_accuracy: 0.3180 - val_loss: 1.8656 - val_sparse_categorical_accuracy: 0.3353
# Epoch 31/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9176 - sparse_categorical_accuracy: 0.3189 - val_loss: 1.8615 - val_sparse_categorical_accuracy: 0.3359
# Epoch 32/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9133 - sparse_categorical_accuracy: 0.3204 - val_loss: 1.8567 - val_sparse_categorical_accuracy: 0.3373
# Epoch 33/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9108 - sparse_categorical_accuracy: 0.3215 - val_loss: 1.8513 - val_sparse_categorical_accuracy: 0.3387
# Epoch 34/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9069 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.8494 - val_sparse_categorical_accuracy: 0.3395
# Epoch 35/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9040 - sparse_categorical_accuracy: 0.3236 - val_loss: 1.8474 - val_sparse_categorical_accuracy: 0.3413
# Epoch 36/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.9012 - sparse_categorical_accuracy: 0.3252 - val_loss: 1.8444 - val_sparse_categorical_accuracy: 0.3414
# Epoch 37/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8977 - sparse_categorical_accuracy: 0.3261 - val_loss: 1.8412 - val_sparse_categorical_accuracy: 0.3433
# Epoch 38/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8953 - sparse_categorical_accuracy: 0.3275 - val_loss: 1.8379 - val_sparse_categorical_accuracy: 0.3446
# Epoch 39/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8923 - sparse_categorical_accuracy: 0.3285 - val_loss: 1.8348 - val_sparse_categorical_accuracy: 0.3455
# Epoch 40/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8904 - sparse_categorical_accuracy: 0.3294 - val_loss: 1.8302 - val_sparse_categorical_accuracy: 0.3473
# Epoch 41/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8880 - sparse_categorical_accuracy: 0.3305 - val_loss: 1.8298 - val_sparse_categorical_accuracy: 0.3478
# Epoch 42/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8850 - sparse_categorical_accuracy: 0.3310 - val_loss: 1.8252 - val_sparse_categorical_accuracy: 0.3503
# Epoch 43/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8825 - sparse_categorical_accuracy: 0.3324 - val_loss: 1.8243 - val_sparse_categorical_accuracy: 0.3510
# Epoch 44/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8806 - sparse_categorical_accuracy: 0.3337 - val_loss: 1.8219 - val_sparse_categorical_accuracy: 0.3511
# Epoch 45/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8794 - sparse_categorical_accuracy: 0.3340 - val_loss: 1.8199 - val_sparse_categorical_accuracy: 0.3515
# Epoch 46/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8775 - sparse_categorical_accuracy: 0.3347 - val_loss: 1.8193 - val_sparse_categorical_accuracy: 0.3523
# Epoch 47/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8759 - sparse_categorical_accuracy: 0.3357 - val_loss: 1.8159 - val_sparse_categorical_accuracy: 0.3536
# Epoch 48/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8744 - sparse_categorical_accuracy: 0.3354 - val_loss: 1.8145 - val_sparse_categorical_accuracy: 0.3539
# Epoch 49/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8722 - sparse_categorical_accuracy: 0.3372 - val_loss: 1.8132 - val_sparse_categorical_accuracy: 0.3553
# Epoch 50/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8708 - sparse_categorical_accuracy: 0.3377 - val_loss: 1.8113 - val_sparse_categorical_accuracy: 0.3560
# Epoch 51/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8696 - sparse_categorical_accuracy: 0.3382 - val_loss: 1.8105 - val_sparse_categorical_accuracy: 0.3565
# Epoch 52/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8687 - sparse_categorical_accuracy: 0.3390 - val_loss: 1.8097 - val_sparse_categorical_accuracy: 0.3564
# Epoch 53/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8663 - sparse_categorical_accuracy: 0.3397 - val_loss: 1.8085 - val_sparse_categorical_accuracy: 0.3567
# Epoch 54/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8654 - sparse_categorical_accuracy: 0.3398 - val_loss: 1.8078 - val_sparse_categorical_accuracy: 0.3574
# Epoch 55/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8644 - sparse_categorical_accuracy: 0.3403 - val_loss: 1.8072 - val_sparse_categorical_accuracy: 0.3579
# Epoch 56/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8632 - sparse_categorical_accuracy: 0.3414 - val_loss: 1.8045 - val_sparse_categorical_accuracy: 0.3590
# Epoch 57/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8621 - sparse_categorical_accuracy: 0.3416 - val_loss: 1.8035 - val_sparse_categorical_accuracy: 0.3591
# Epoch 58/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8609 - sparse_categorical_accuracy: 0.3418 - val_loss: 1.8023 - val_sparse_categorical_accuracy: 0.3608
# Epoch 59/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8595 - sparse_categorical_accuracy: 0.3426 - val_loss: 1.8023 - val_sparse_categorical_accuracy: 0.3605
# Epoch 60/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8591 - sparse_categorical_accuracy: 0.3427 - val_loss: 1.8018 - val_sparse_categorical_accuracy: 0.3604
# Epoch 61/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8581 - sparse_categorical_accuracy: 0.3437 - val_loss: 1.8010 - val_sparse_categorical_accuracy: 0.3604
# Epoch 62/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8568 - sparse_categorical_accuracy: 0.3438 - val_loss: 1.7986 - val_sparse_categorical_accuracy: 0.3617
# Epoch 63/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8558 - sparse_categorical_accuracy: 0.3442 - val_loss: 1.7961 - val_sparse_categorical_accuracy: 0.3638
# Epoch 64/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8548 - sparse_categorical_accuracy: 0.3450 - val_loss: 1.7976 - val_sparse_categorical_accuracy: 0.3614
# Epoch 65/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8538 - sparse_categorical_accuracy: 0.3454 - val_loss: 1.7963 - val_sparse_categorical_accuracy: 0.3634
# Epoch 66/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8522 - sparse_categorical_accuracy: 0.3460 - val_loss: 1.7951 - val_sparse_categorical_accuracy: 0.3635
# Epoch 67/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8518 - sparse_categorical_accuracy: 0.3460 - val_loss: 1.7941 - val_sparse_categorical_accuracy: 0.3645
# Epoch 68/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8513 - sparse_categorical_accuracy: 0.3462 - val_loss: 1.7927 - val_sparse_categorical_accuracy: 0.3643
# Epoch 69/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8504 - sparse_categorical_accuracy: 0.3468 - val_loss: 1.7929 - val_sparse_categorical_accuracy: 0.3641
# Epoch 70/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8497 - sparse_categorical_accuracy: 0.3470 - val_loss: 1.7919 - val_sparse_categorical_accuracy: 0.3653
# Epoch 71/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8481 - sparse_categorical_accuracy: 0.3475 - val_loss: 1.7904 - val_sparse_categorical_accuracy: 0.3665
# Epoch 72/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8481 - sparse_categorical_accuracy: 0.3475 - val_loss: 1.7921 - val_sparse_categorical_accuracy: 0.3643
# Epoch 73/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8476 - sparse_categorical_accuracy: 0.3478 - val_loss: 1.7893 - val_sparse_categorical_accuracy: 0.3663
# Epoch 74/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8464 - sparse_categorical_accuracy: 0.3487 - val_loss: 1.7904 - val_sparse_categorical_accuracy: 0.3658
# Epoch 75/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8449 - sparse_categorical_accuracy: 0.3487 - val_loss: 1.7883 - val_sparse_categorical_accuracy: 0.3657
# Epoch 76/1000
# 15290/15290 [==============================] - 26s 2ms/step - loss: 1.8446 - sparse_categorical_accuracy: 0.3492 - val_loss: 1.7868 - val_sparse_categorical_accuracy: 0.3673
# Epoch 77/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8439 - sparse_categorical_accuracy: 0.3488 - val_loss: 1.7867 - val_sparse_categorical_accuracy: 0.3663
# Epoch 78/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8435 - sparse_categorical_accuracy: 0.3501 - val_loss: 1.7873 - val_sparse_categorical_accuracy: 0.3672
# Epoch 79/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8424 - sparse_categorical_accuracy: 0.3506 - val_loss: 1.7855 - val_sparse_categorical_accuracy: 0.3674
# Epoch 80/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8420 - sparse_categorical_accuracy: 0.3508 - val_loss: 1.7834 - val_sparse_categorical_accuracy: 0.3686
# Epoch 81/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8409 - sparse_categorical_accuracy: 0.3507 - val_loss: 1.7842 - val_sparse_categorical_accuracy: 0.3683
# Epoch 82/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8406 - sparse_categorical_accuracy: 0.3514 - val_loss: 1.7818 - val_sparse_categorical_accuracy: 0.3690
# Epoch 83/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8398 - sparse_categorical_accuracy: 0.3513 - val_loss: 1.7806 - val_sparse_categorical_accuracy: 0.3699
# Epoch 84/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8384 - sparse_categorical_accuracy: 0.3517 - val_loss: 1.7827 - val_sparse_categorical_accuracy: 0.3694
# Epoch 85/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8380 - sparse_categorical_accuracy: 0.3521 - val_loss: 1.7824 - val_sparse_categorical_accuracy: 0.3701
# Epoch 86/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8375 - sparse_categorical_accuracy: 0.3526 - val_loss: 1.7831 - val_sparse_categorical_accuracy: 0.3689
# Epoch 87/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8374 - sparse_categorical_accuracy: 0.3530 - val_loss: 1.7803 - val_sparse_categorical_accuracy: 0.3704
# Epoch 88/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8367 - sparse_categorical_accuracy: 0.3527 - val_loss: 1.7786 - val_sparse_categorical_accuracy: 0.3714
# Epoch 89/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8362 - sparse_categorical_accuracy: 0.3536 - val_loss: 1.7808 - val_sparse_categorical_accuracy: 0.3711
# Epoch 90/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8352 - sparse_categorical_accuracy: 0.3537 - val_loss: 1.7768 - val_sparse_categorical_accuracy: 0.3720
# Epoch 91/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8349 - sparse_categorical_accuracy: 0.3539 - val_loss: 1.7779 - val_sparse_categorical_accuracy: 0.3714
# Epoch 92/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8342 - sparse_categorical_accuracy: 0.3544 - val_loss: 1.7757 - val_sparse_categorical_accuracy: 0.3730
# Epoch 93/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8333 - sparse_categorical_accuracy: 0.3545 - val_loss: 1.7754 - val_sparse_categorical_accuracy: 0.3727
# Epoch 94/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8332 - sparse_categorical_accuracy: 0.3551 - val_loss: 1.7758 - val_sparse_categorical_accuracy: 0.3734
# Epoch 95/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8328 - sparse_categorical_accuracy: 0.3553 - val_loss: 1.7766 - val_sparse_categorical_accuracy: 0.3716
# Epoch 96/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8315 - sparse_categorical_accuracy: 0.3556 - val_loss: 1.7753 - val_sparse_categorical_accuracy: 0.3728
# Epoch 97/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8315 - sparse_categorical_accuracy: 0.3556 - val_loss: 1.7748 - val_sparse_categorical_accuracy: 0.3734
# Epoch 98/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8308 - sparse_categorical_accuracy: 0.3558 - val_loss: 1.7742 - val_sparse_categorical_accuracy: 0.3731
# Epoch 99/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8306 - sparse_categorical_accuracy: 0.3565 - val_loss: 1.7733 - val_sparse_categorical_accuracy: 0.3740
# Epoch 100/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8296 - sparse_categorical_accuracy: 0.3557 - val_loss: 1.7737 - val_sparse_categorical_accuracy: 0.3734
# Epoch 101/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8303 - sparse_categorical_accuracy: 0.3563 - val_loss: 1.7705 - val_sparse_categorical_accuracy: 0.3750
# Epoch 102/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8291 - sparse_categorical_accuracy: 0.3571 - val_loss: 1.7721 - val_sparse_categorical_accuracy: 0.3743
# Epoch 103/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8284 - sparse_categorical_accuracy: 0.3569 - val_loss: 1.7714 - val_sparse_categorical_accuracy: 0.3748
# Epoch 104/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8281 - sparse_categorical_accuracy: 0.3575 - val_loss: 1.7699 - val_sparse_categorical_accuracy: 0.3756
# Epoch 105/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8273 - sparse_categorical_accuracy: 0.3579 - val_loss: 1.7697 - val_sparse_categorical_accuracy: 0.3753
# Epoch 106/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8273 - sparse_categorical_accuracy: 0.3573 - val_loss: 1.7685 - val_sparse_categorical_accuracy: 0.3761
# Epoch 107/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8267 - sparse_categorical_accuracy: 0.3577 - val_loss: 1.7709 - val_sparse_categorical_accuracy: 0.3765
# Epoch 108/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8258 - sparse_categorical_accuracy: 0.3580 - val_loss: 1.7718 - val_sparse_categorical_accuracy: 0.3748
# Epoch 109/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8253 - sparse_categorical_accuracy: 0.3584 - val_loss: 1.7712 - val_sparse_categorical_accuracy: 0.3741
# Epoch 110/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8249 - sparse_categorical_accuracy: 0.3584 - val_loss: 1.7668 - val_sparse_categorical_accuracy: 0.3775
# Epoch 111/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8251 - sparse_categorical_accuracy: 0.3591 - val_loss: 1.7693 - val_sparse_categorical_accuracy: 0.3755
# Epoch 112/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8243 - sparse_categorical_accuracy: 0.3589 - val_loss: 1.7678 - val_sparse_categorical_accuracy: 0.3763
# Epoch 113/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8240 - sparse_categorical_accuracy: 0.3594 - val_loss: 1.7668 - val_sparse_categorical_accuracy: 0.3772
# Epoch 114/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8241 - sparse_categorical_accuracy: 0.3596 - val_loss: 1.7661 - val_sparse_categorical_accuracy: 0.3778
# Epoch 115/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8233 - sparse_categorical_accuracy: 0.3599 - val_loss: 1.7685 - val_sparse_categorical_accuracy: 0.3758
# Epoch 116/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8227 - sparse_categorical_accuracy: 0.3600 - val_loss: 1.7645 - val_sparse_categorical_accuracy: 0.3782
# Epoch 117/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8223 - sparse_categorical_accuracy: 0.3601 - val_loss: 1.7645 - val_sparse_categorical_accuracy: 0.3776
# Epoch 118/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8219 - sparse_categorical_accuracy: 0.3606 - val_loss: 1.7638 - val_sparse_categorical_accuracy: 0.3786
# Epoch 119/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8218 - sparse_categorical_accuracy: 0.3609 - val_loss: 1.7622 - val_sparse_categorical_accuracy: 0.3791
# Epoch 120/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8206 - sparse_categorical_accuracy: 0.3607 - val_loss: 1.7635 - val_sparse_categorical_accuracy: 0.3788
# Epoch 121/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8211 - sparse_categorical_accuracy: 0.3617 - val_loss: 1.7636 - val_sparse_categorical_accuracy: 0.3787
# Epoch 122/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8200 - sparse_categorical_accuracy: 0.3612 - val_loss: 1.7622 - val_sparse_categorical_accuracy: 0.3791
# Epoch 123/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8194 - sparse_categorical_accuracy: 0.3618 - val_loss: 1.7597 - val_sparse_categorical_accuracy: 0.3798
# Epoch 124/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8188 - sparse_categorical_accuracy: 0.3619 - val_loss: 1.7620 - val_sparse_categorical_accuracy: 0.3795
# Epoch 125/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8184 - sparse_categorical_accuracy: 0.3623 - val_loss: 1.7600 - val_sparse_categorical_accuracy: 0.3804
# Epoch 126/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8176 - sparse_categorical_accuracy: 0.3627 - val_loss: 1.7591 - val_sparse_categorical_accuracy: 0.3807
# Epoch 127/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8174 - sparse_categorical_accuracy: 0.3628 - val_loss: 1.7589 - val_sparse_categorical_accuracy: 0.3814
# Epoch 128/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8169 - sparse_categorical_accuracy: 0.3632 - val_loss: 1.7597 - val_sparse_categorical_accuracy: 0.3811
# Epoch 129/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8167 - sparse_categorical_accuracy: 0.3632 - val_loss: 1.7590 - val_sparse_categorical_accuracy: 0.3812
# Epoch 130/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8163 - sparse_categorical_accuracy: 0.3639 - val_loss: 1.7573 - val_sparse_categorical_accuracy: 0.3816
# Epoch 131/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8154 - sparse_categorical_accuracy: 0.3643 - val_loss: 1.7556 - val_sparse_categorical_accuracy: 0.3826
# Epoch 132/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8152 - sparse_categorical_accuracy: 0.3641 - val_loss: 1.7568 - val_sparse_categorical_accuracy: 0.3813
# Epoch 133/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8143 - sparse_categorical_accuracy: 0.3648 - val_loss: 1.7553 - val_sparse_categorical_accuracy: 0.3831
# Epoch 134/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8143 - sparse_categorical_accuracy: 0.3644 - val_loss: 1.7567 - val_sparse_categorical_accuracy: 0.3832
# Epoch 135/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8139 - sparse_categorical_accuracy: 0.3649 - val_loss: 1.7534 - val_sparse_categorical_accuracy: 0.3836
# Epoch 136/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8131 - sparse_categorical_accuracy: 0.3649 - val_loss: 1.7542 - val_sparse_categorical_accuracy: 0.3835
# Epoch 137/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8129 - sparse_categorical_accuracy: 0.3653 - val_loss: 1.7533 - val_sparse_categorical_accuracy: 0.3835
# Epoch 138/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8135 - sparse_categorical_accuracy: 0.3653 - val_loss: 1.7527 - val_sparse_categorical_accuracy: 0.3839
# Epoch 139/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8119 - sparse_categorical_accuracy: 0.3662 - val_loss: 1.7508 - val_sparse_categorical_accuracy: 0.3856
# Epoch 140/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8123 - sparse_categorical_accuracy: 0.3660 - val_loss: 1.7498 - val_sparse_categorical_accuracy: 0.3857
# Epoch 141/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8111 - sparse_categorical_accuracy: 0.3667 - val_loss: 1.7498 - val_sparse_categorical_accuracy: 0.3855
# Epoch 142/1000
# 15290/15290 [==============================] - 26s 2ms/step - loss: 1.8104 - sparse_categorical_accuracy: 0.3666 - val_loss: 1.7504 - val_sparse_categorical_accuracy: 0.3851
# Epoch 143/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8108 - sparse_categorical_accuracy: 0.3670 - val_loss: 1.7484 - val_sparse_categorical_accuracy: 0.3864
# Epoch 144/1000
# 15290/15290 [==============================] - 26s 2ms/step - loss: 1.8096 - sparse_categorical_accuracy: 0.3669 - val_loss: 1.7489 - val_sparse_categorical_accuracy: 0.3863
# Epoch 145/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8097 - sparse_categorical_accuracy: 0.3670 - val_loss: 1.7487 - val_sparse_categorical_accuracy: 0.3857
# Epoch 146/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8091 - sparse_categorical_accuracy: 0.3669 - val_loss: 1.7467 - val_sparse_categorical_accuracy: 0.3862
# Epoch 147/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8084 - sparse_categorical_accuracy: 0.3673 - val_loss: 1.7459 - val_sparse_categorical_accuracy: 0.3875
# Epoch 148/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8085 - sparse_categorical_accuracy: 0.3674 - val_loss: 1.7457 - val_sparse_categorical_accuracy: 0.3868
# Epoch 149/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8084 - sparse_categorical_accuracy: 0.3677 - val_loss: 1.7462 - val_sparse_categorical_accuracy: 0.3868
# Epoch 150/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8071 - sparse_categorical_accuracy: 0.3680 - val_loss: 1.7481 - val_sparse_categorical_accuracy: 0.3876
# Epoch 151/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8069 - sparse_categorical_accuracy: 0.3681 - val_loss: 1.7461 - val_sparse_categorical_accuracy: 0.3868
# Epoch 152/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8070 - sparse_categorical_accuracy: 0.3681 - val_loss: 1.7439 - val_sparse_categorical_accuracy: 0.3887
# Epoch 153/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8069 - sparse_categorical_accuracy: 0.3686 - val_loss: 1.7510 - val_sparse_categorical_accuracy: 0.3874
# Epoch 154/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8061 - sparse_categorical_accuracy: 0.3686 - val_loss: 1.7446 - val_sparse_categorical_accuracy: 0.3888
# Epoch 155/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8057 - sparse_categorical_accuracy: 0.3690 - val_loss: 1.7438 - val_sparse_categorical_accuracy: 0.3891
# Epoch 156/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8066 - sparse_categorical_accuracy: 0.3687 - val_loss: 1.7411 - val_sparse_categorical_accuracy: 0.3895
# Epoch 157/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8057 - sparse_categorical_accuracy: 0.3693 - val_loss: 1.7420 - val_sparse_categorical_accuracy: 0.3904
# Epoch 158/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8048 - sparse_categorical_accuracy: 0.3693 - val_loss: 1.7413 - val_sparse_categorical_accuracy: 0.3880
# Epoch 159/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8050 - sparse_categorical_accuracy: 0.3695 - val_loss: 1.7403 - val_sparse_categorical_accuracy: 0.3904
# Epoch 160/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8045 - sparse_categorical_accuracy: 0.3698 - val_loss: 1.7396 - val_sparse_categorical_accuracy: 0.3898
# Epoch 161/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8039 - sparse_categorical_accuracy: 0.3695 - val_loss: 1.7409 - val_sparse_categorical_accuracy: 0.3884
# Epoch 162/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8039 - sparse_categorical_accuracy: 0.3698 - val_loss: 1.7397 - val_sparse_categorical_accuracy: 0.3898
# Epoch 163/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8035 - sparse_categorical_accuracy: 0.3708 - val_loss: 1.7402 - val_sparse_categorical_accuracy: 0.3911
# Epoch 164/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8031 - sparse_categorical_accuracy: 0.3703 - val_loss: 1.7365 - val_sparse_categorical_accuracy: 0.3912
# Epoch 165/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8025 - sparse_categorical_accuracy: 0.3707 - val_loss: 1.7396 - val_sparse_categorical_accuracy: 0.3904
# Epoch 166/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8020 - sparse_categorical_accuracy: 0.3710 - val_loss: 1.7386 - val_sparse_categorical_accuracy: 0.3892
# Epoch 167/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8015 - sparse_categorical_accuracy: 0.3709 - val_loss: 1.7376 - val_sparse_categorical_accuracy: 0.3913
# Epoch 168/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8014 - sparse_categorical_accuracy: 0.3709 - val_loss: 1.7373 - val_sparse_categorical_accuracy: 0.3903
# Epoch 169/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8007 - sparse_categorical_accuracy: 0.3712 - val_loss: 1.7364 - val_sparse_categorical_accuracy: 0.3918
# Epoch 170/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8002 - sparse_categorical_accuracy: 0.3714 - val_loss: 1.7364 - val_sparse_categorical_accuracy: 0.3906
# Epoch 171/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7997 - sparse_categorical_accuracy: 0.3716 - val_loss: 1.7372 - val_sparse_categorical_accuracy: 0.3907
# Epoch 172/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.8003 - sparse_categorical_accuracy: 0.3711 - val_loss: 1.7345 - val_sparse_categorical_accuracy: 0.3919
# Epoch 173/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7996 - sparse_categorical_accuracy: 0.3715 - val_loss: 1.7352 - val_sparse_categorical_accuracy: 0.3913
# Epoch 174/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7988 - sparse_categorical_accuracy: 0.3716 - val_loss: 1.7329 - val_sparse_categorical_accuracy: 0.3919
# Epoch 175/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7990 - sparse_categorical_accuracy: 0.3720 - val_loss: 1.7339 - val_sparse_categorical_accuracy: 0.3920
# Epoch 176/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7976 - sparse_categorical_accuracy: 0.3721 - val_loss: 1.7327 - val_sparse_categorical_accuracy: 0.3924
# Epoch 177/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7977 - sparse_categorical_accuracy: 0.3725 - val_loss: 1.7315 - val_sparse_categorical_accuracy: 0.3940
# Epoch 178/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7968 - sparse_categorical_accuracy: 0.3726 - val_loss: 1.7289 - val_sparse_categorical_accuracy: 0.3950
# Epoch 179/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7971 - sparse_categorical_accuracy: 0.3724 - val_loss: 1.7322 - val_sparse_categorical_accuracy: 0.3928
# Epoch 180/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7966 - sparse_categorical_accuracy: 0.3730 - val_loss: 1.7307 - val_sparse_categorical_accuracy: 0.3929
# Epoch 181/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7966 - sparse_categorical_accuracy: 0.3730 - val_loss: 1.7294 - val_sparse_categorical_accuracy: 0.3939
# Epoch 182/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7964 - sparse_categorical_accuracy: 0.3732 - val_loss: 1.7280 - val_sparse_categorical_accuracy: 0.3940
# Epoch 183/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7962 - sparse_categorical_accuracy: 0.3729 - val_loss: 1.7282 - val_sparse_categorical_accuracy: 0.3950
# Epoch 184/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7956 - sparse_categorical_accuracy: 0.3730 - val_loss: 1.7281 - val_sparse_categorical_accuracy: 0.3946
# Epoch 185/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7955 - sparse_categorical_accuracy: 0.3734 - val_loss: 1.7289 - val_sparse_categorical_accuracy: 0.3942
# Epoch 186/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7957 - sparse_categorical_accuracy: 0.3734 - val_loss: 1.7266 - val_sparse_categorical_accuracy: 0.3959
# Epoch 187/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7945 - sparse_categorical_accuracy: 0.3736 - val_loss: 1.7287 - val_sparse_categorical_accuracy: 0.3949
# Epoch 188/1000
# 15290/15290 [==============================] - 26s 2ms/step - loss: 1.7940 - sparse_categorical_accuracy: 0.3733 - val_loss: 1.7275 - val_sparse_categorical_accuracy: 0.3946
# Epoch 189/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7946 - sparse_categorical_accuracy: 0.3736 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.3958
# Epoch 190/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7944 - sparse_categorical_accuracy: 0.3739 - val_loss: 1.7274 - val_sparse_categorical_accuracy: 0.3948
# Epoch 191/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7941 - sparse_categorical_accuracy: 0.3741 - val_loss: 1.7275 - val_sparse_categorical_accuracy: 0.3949
# Epoch 192/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7925 - sparse_categorical_accuracy: 0.3743 - val_loss: 1.7246 - val_sparse_categorical_accuracy: 0.3963
# Epoch 193/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7933 - sparse_categorical_accuracy: 0.3743 - val_loss: 1.7262 - val_sparse_categorical_accuracy: 0.3960
# Epoch 194/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7931 - sparse_categorical_accuracy: 0.3742 - val_loss: 1.7257 - val_sparse_categorical_accuracy: 0.3963
# Epoch 195/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7927 - sparse_categorical_accuracy: 0.3742 - val_loss: 1.7240 - val_sparse_categorical_accuracy: 0.3961
# Epoch 196/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7926 - sparse_categorical_accuracy: 0.3740 - val_loss: 1.7245 - val_sparse_categorical_accuracy: 0.3965
# Epoch 197/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7928 - sparse_categorical_accuracy: 0.3747 - val_loss: 1.7272 - val_sparse_categorical_accuracy: 0.3961
# Epoch 198/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7923 - sparse_categorical_accuracy: 0.3752 - val_loss: 1.7277 - val_sparse_categorical_accuracy: 0.3937
# Epoch 199/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7917 - sparse_categorical_accuracy: 0.3750 - val_loss: 1.7248 - val_sparse_categorical_accuracy: 0.3960
# Epoch 200/1000
# 15290/15290 [==============================] - 27s 2ms/step - loss: 1.7914 - sparse_categorical_accuracy: 0.3748 - val_loss: 1.7276 - val_sparse_categorical_accuracy: 0.3932
# Epoch 00200: early stopping

# %%
evalu_val = model.evaluate(X_val, Y_val)
metrics = model.metrics_names
print(f"{metrics[1]}: {evalu_val[1]}")
print(f"{metrics[0]}: {evalu_val[0]}")
# Out:
# 9556/9556 [==============================] - 11s 1ms/step - loss: 1.7256 - sparse_categorical_accuracy: 0.3956
# sparse_categorical_accuracy: 0.39563417434692383
# loss: 1.7255982160568237

# %%
evalu_train = model.evaluate(X_train, Y_train)
metrics = model.metrics_names
print(f"{metrics[1]}: {evalu_train[1]}")
print(f"{metrics[0]}: {evalu_train[0]}")
# Out:
# 38224/38224 [==============================] - 42s 1ms/step - loss: 1.7245 - sparse_categorical_accuracy: 0.3943
# sparse_categorical_accuracy: 0.39431723952293396
# loss: 1.7244577407836914

# %%
compare = pd.DataFrame()
output = model.predict(X_val)
#compare['output'] = output
predict_lab = []
predict_name = []
actual_name = []
sig_prob = []
prob_ratio = []
for i in range(output.shape[0]):
    label = np.argmax(output[i])
    predict_lab.append(label)
    predict_name.append(mc_labels[label])
    actual_name.append(mc_labels[Y_val[i]])
    sum_prob = 0
    for j in range(14):
        sum_prob += output[i][j+1]
    prob_ratio.append(output[i][0] / sum_prob)
    sig_prob.append(output[i][0])
compare['predicted_label'] = predict_lab
compare['actual_label'] = Y_val
compare['predicted_name'] = predict_name
compare['actual_name'] = actual_name
compare['sig_prob'] = sig_prob
compare['prob_ratio'] = prob_ratio

# %%
print(predict_lab.count(0) / len(predict_lab))
print(np.count_nonzero(Y_val == 0) / Y_val.shape[0])
print(np.count_nonzero(Y_train == 0) / Y_train.shape[0])
print(np.count_nonzero(Y_val == 0) + np.count_nonzero(Y_train == 0))
# Out:
# 0.08450054777049235
# 0.0747257059698808
# 0.0754167358194544
# 115095

# %%
compare.sample(n=50)
# Out:
#         predicted_label  actual_label     predicted_name        actual_name  \
# 219579                6             3             TTJets            ttHToGG
# 13587                 0             0         GluGluToHH         GluGluToHH
# 267586               12            12  DiPhotonJetsBox1B  DiPhotonJetsBox1B
# 64960                 5            11        GluGluHtoGG    DiPhotonJetsBox
# 91564                12             1  DiPhotonJetsBox1B            VBFToHH
# 170500                1             1            VBFToHH            VBFToHH
# 10885                 5             4        GluGluHtoGG           VBFHToGG
# 83886                 6             7             TTJets            TTGJets
# 91785                 0            13         GluGluToHH  DiPhotonJetsBox2B
# 169287               11             3    DiPhotonJetsBox            ttHToGG
# 201878               11             3    DiPhotonJetsBox            ttHToGG
# 305115                6             3             TTJets            ttHToGG
# 48374                 6            11             TTJets    DiPhotonJetsBox
# 259414               11            11    DiPhotonJetsBox    DiPhotonJetsBox
# 32072                11            11    DiPhotonJetsBox    DiPhotonJetsBox
# 149804               11             1    DiPhotonJetsBox            VBFToHH
# 248543                0             7         GluGluToHH            TTGJets
# 102151               11            11    DiPhotonJetsBox    DiPhotonJetsBox
# 62109                 0            12         GluGluToHH  DiPhotonJetsBox1B
# 268527                5             5        GluGluHtoGG        GluGluHtoGG
# 254757               11             4    DiPhotonJetsBox           VBFHToGG
# 292176                6            11             TTJets    DiPhotonJetsBox
# 252176                2             5             VHToGG        GluGluHtoGG
# 87885                 6             6             TTJets             TTJets
# 174645                5             4        GluGluHtoGG           VBFHToGG
# 241312                6             5             TTJets        GluGluHtoGG
# 74732                 3             1            ttHToGG            VBFToHH
# 191567                6             1             TTJets            VBFToHH
# 7768                  6             7             TTJets            TTGJets
# 275965                6            12             TTJets  DiPhotonJetsBox1B
# 185476                2             2             VHToGG             VHToGG
# 17910                11             2    DiPhotonJetsBox             VHToGG
# 164412                1             7            VBFToHH            TTGJets
# 72595                 0             6         GluGluToHH             TTJets
# 242625                6             6             TTJets             TTJets
# 104521                6             6             TTJets             TTJets
# 189033                2             0             VHToGG         GluGluToHH
# 107057                6             7             TTJets            TTGJets
# 49271                 2             2             VHToGG             VHToGG
# 18417                 2            11             VHToGG    DiPhotonJetsBox
# 151888                6             6             TTJets             TTJets
# 111997                6             3             TTJets            ttHToGG
# 42382                 2            11             VHToGG    DiPhotonJetsBox
# 70114                11            11    DiPhotonJetsBox    DiPhotonJetsBox
# 212684                5             4        GluGluHtoGG           VBFHToGG
# 198648               11            10    DiPhotonJetsBox         GJet_BigPt
# 222104                6             6             TTJets             TTJets
# 117583               11             2    DiPhotonJetsBox             VHToGG
# 105556               12             3  DiPhotonJetsBox1B            ttHToGG
# 75735                11             4    DiPhotonJetsBox           VBFHToGG
#
#         sig_prob  prob_ratio
# 219579  0.048527    0.051002
# 13587   0.529122    1.123693
# 267586  0.043671    0.045665
# 64960   0.002051    0.002055
# 91564   0.034320    0.035540
# 170500  0.357128    0.555519
# 10885   0.003505    0.003517
# 83886   0.001580    0.001582
# 91785   0.286061    0.400680
# 169287  0.003008    0.003017
# 201878  0.008167    0.008234
# 305115  0.001595    0.001597
# 48374   0.008326    0.008396
# 259414  0.005414    0.005443
# 32072   0.018494    0.018843
# 149804  0.022827    0.023360
# 248543  0.474238    0.902001
# 102151  0.002302    0.002308
# 62109   0.323237    0.477621
# 268527  0.006796    0.006842
# 254757  0.005822    0.005856
# 292176  0.003083    0.003092
# 252176  0.011890    0.012033
# 87885   0.008901    0.008981
# 174645  0.001422    0.001424
# 241312  0.007238    0.007291
# 74732   0.070313    0.075631
# 191567  0.050134    0.052780
# 7768    0.001188    0.001190
# 275965  0.038533    0.040078
# 185476  0.023588    0.024158
# 17910   0.002187    0.002192
# 164412  0.176936    0.214973
# 72595   0.468878    0.882806
# 242625  0.038352    0.039882
# 104521  0.043987    0.046011
# 189033  0.073979    0.079889
# 107057  0.003891    0.003906
# 49271   0.007930    0.007993
# 18417   0.035039    0.036311
# 151888  0.000815    0.000816
# 111997  0.019460    0.019847
# 42382   0.004331    0.004350
# 70114   0.020656    0.021092
# 212684  0.021719    0.022201
# 198648  0.003824    0.003838
# 222104  0.001889    0.001892
# 117583  0.018847    0.019209
# 105556  0.045323    0.047474
# 75735   0.010164    0.010269

# %%
y_pred = []
y_act = []
for i in range(Y_val.shape[0]):
    if Y_val[i] == 0:
        y_act.append(1)
    else:
        y_act.append(0)
    if predict_lab[i] == 0:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %% [markdown]
# ## Plotting Results

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_act, y_pred, sample_weight = X_val_weight)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
# ROC curve
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('combine ROC curve')
plt.legend(loc='best')
plt.savefig(fname = f'ROC_Plts/full/multi_ROC_curve.png', format='png')
plt.show()

# Zoom in view of the upper left corner ROC curve
plt.figure(2)
plt.xlim(0, 0.5)
plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label= 'Keras (area = {:.3f})'.format(auc_keras))
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.title('comvine ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.savefig(fname = f'ROC_Plts/full/multi_ROC_curve_zoom')
plt.show()

# plot loss vs epoch
plt.figure(3)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc="best")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('combine Loss vs. Epoch')
plt.savefig(fname = f'Epoch_Plts/full/multi_loss_epoch.png', format='png')
plt.show()

# plot accuracy vs epoch
plt.figure(4)
plt.plot(history.history['sparse_categorical_accuracy'], label='acc')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_acc')
plt.legend(loc="best")
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.title('combine Acc vs. Epoch')
plt.savefig(fname = f'Epoch_Plts/full/multi_acc_epoch.png', format='png')
plt.show()

# %%
total_weight = np.sum(full_df.loc[:, b'genweight'].values)
test_total_weight = np.sum(X_val_weight)
scale_weight = total_weight / test_total_weight

# %%
# Make copy of dataframe
X_full = full_df.values
X_train_full, X_val_full, y_ph_1, y_ph_2 = train_test_split(X_full, Y, test_size = 0.2, random_state=random_seed)
X_val_full_df = pd.DataFrame(X_val_full, columns = list(full_df.columns))

result_df = pd.DataFrame()
for column in list(full_df.columns):
    result_df[column] = X_val_full_df.loc[:, column].values
result_df[b'genweight_scale'] = X_val_full_df.loc[:, b'genweight'] * scale_weight
result_df[b'actual_label'] = Y_val
result_df[b'predicted_label'] = predict_lab
result_df[b'sig_prob'] = sig_prob
result_df[b'prob_ratio'] = prob_ratio

# %%
result_df.head()
# Out:
#   b'leading_photon_pt' b'subleading_photon_pt' b'diphoton_pt'  \
# 0              100.653                 77.6155        171.578
# 1              130.761                 39.5083        150.451
# 2              84.8645                 46.9327        68.5444
# 3              95.5568                 53.9212         142.03
# 4              48.7047                 35.4135         15.585
#
#   b'diphoton_mass' b'leading_bjet_pt' b'subleading_bjet_pt' b'dibjet_pt'  \
# 0          117.614                 98               60.7812      38.5725
# 1          130.177               69.5                39.625      75.1843
# 2          126.857             91.875               34.5312       87.247
# 3          106.634              121.5               34.8125      148.869
# 4          137.343            54.2188               52.2812       41.845
#
#   b'dibjet_mass' b'leading_bjet_pt_corr' b'subleading_bjet_pt_corr'  ...  \
# 0        156.278                  98.957                    67.6666  ...
# 1        100.475                  73.708                    56.1096  ...
# 2        93.4732                 94.4769                    29.7765  ...
# 3        93.0338                 123.517                    35.0505  ...
# 4        123.469                 56.1778                    59.0206  ...
#
#   b'run' b'lumi'  b'event'           b'label' b'label_num' b'genweight_scale'  \
# 0      1     107    106462  DiPhotonJetsBox1B           12           0.095769
# 1      1     498   1491548         TTGG_0Jets            8         0.00294742
# 2      1   14435   4546719        GluGluHtoGG            5          0.0302446
# 3      1  226618  12237339            TTGJets            7           0.149898
# 4      1    6935   9909739             TTJets            6            -2.0635
#
#   b'actual_label' b'predicted_label' b'sig_prob' b'prob_ratio'
# 0              12                  3    0.165959      0.198982
# 1               8                  3    0.024795      0.025426
# 2               5                  4    0.010506      0.010617
# 3               7                  3    0.039569      0.041199
# 4               6                  6    0.005762      0.005796
#
# [5 rows x 75 columns]

# %%
mc_labels = ['GluGluToHH', 'VBFToHH',
            'VHToGG', 'ttHToGG', 'VBFHToGG', 'GluGluHtoGG',
            'TTJets', 'TTGJets', 'TTGG_0Jets',
            'GJet_SmallPt', 'GJet_BigPt', 'DiPhotonJetsBox', 'DiPhotonJetsBox1B', 'DiPhotonJetsBox2B', 'QCDJets']

for i in range(len(mc_labels)-1):
    sig_df = result_df[result_df[b'actual_label'] == 0]
    samp_df = result_df[result_df[b'actual_label'] == i+1]
    bgd_weight = samp_df.loc[:, b'genweight_scale'].values
    sgl_weight = sig_df.loc[:, b'genweight_scale'].values
    bgd_sig_prob = samp_df.loc[:, b'sig_prob'].values
    sgl_sig_prob = sig_df.loc[:, b'sig_prob'].values
    bgd_prob_rat = samp_df.loc[:, b'prob_ratio'].values
    sgl_prob_rat = sig_df.loc[:, b'prob_ratio'].values
    
    plt.figure(figsize=(9,6))
    plt.hist(bgd_sig_prob, color='blue', weights= bgd_weight, histtype='step', bins = 20, label= f'{mc_labels[i+1]} background', density = True)
    plt.hist(sgl_sig_prob, color='orange', weights= sgl_weight, histtype='step', bins = 20, label= 'ggHH signal', density = True)
    plt.xlabel('probability of being ggHH')
    plt.ylabel('Number of Events')
    plt.legend(loc = 'best')
    plt.title(f'signal probability for {mc_labels[i+1]} background')
    plt.savefig(fname = f'Multi_Prob_Plts/sig_prob_{mc_labels[i+1]}.png', format='png')
    plt.close()
    
    plt.figure(figsize=(9,6))
    plt.hist(bgd_prob_rat, color='blue', weights= bgd_weight, histtype='step', bins = 20, label= f'{mc_labels[i+1]} background', density = True)
    plt.hist(sgl_prob_rat, color='orange', weights= sgl_weight, histtype='step', bins = 20, label= 'ggHH signal', density = True)
    plt.xlabel('probability ratio')
    plt.ylabel('Number of Events')
    plt.legend(loc = 'best')
    plt.title(f'probability ratio for {mc_labels[i+1]} background')
    plt.savefig(fname = f'Multi_Prob_Plts/prob_ratio_{mc_labels[i+1]}.png', format='png')
    plt.close()

# %%
sig_df = result_df[result_df[b'actual_label'] == 0]
bgd_df = result_df[result_df[b'actual_label'] != 0]
bgd_weight = bgd_df.loc[:, b'genweight_scale'].values
sgl_weight = sig_df.loc[:, b'genweight_scale'].values
bgd_sig_prob = bgd_df.loc[:, b'sig_prob'].values
sgl_sig_prob = sig_df.loc[:, b'sig_prob'].values
bgd_prob_rat = bgd_df.loc[:, b'prob_ratio'].values
sgl_prob_rat = sig_df.loc[:, b'prob_ratio'].values

plt.figure(figsize=(9,6))
plt.hist(bgd_sig_prob, color='blue', weights= bgd_weight, histtype='step', bins = 20, label= f'combined background', density = True)
plt.hist(sgl_sig_prob, color='orange', weights= sgl_weight, histtype='step', bins = 20, label= 'ggHH signal', density = True)
plt.xlabel('Probability of being ggHH')
plt.ylabel('Number of Events')
plt.legend(loc = 'best')
plt.title(f'Signal probability for combined background')
plt.savefig(fname = f'Multi_Prob_Plts/sig_prob_combined.png', format='png')
plt.close()

plt.figure(figsize=(9,6))
plt.hist(bgd_prob_rat, color='blue', weights= bgd_weight, histtype='step', bins = 20, label= f'combined background', density = True)
plt.hist(sgl_prob_rat, color='orange', weights= sgl_weight, histtype='step', bins = 20, label= 'ggHH signal', density = True)
plt.xlabel('Probability ratio')
plt.ylabel('Number of Events')
plt.legend(loc = 'best')
plt.title(f'Probability ratio for combined background')
plt.savefig(fname = f'Multi_Prob_Plts/prob_ratio_combined.png', format='png')
plt.close()

# %%
from ROOT import RDF
from ROOT import Internal

result_dict = {key.decode("utf-8"): result_df[key].values for key in list(result_df.columns)}
result_rdf = rt.RDF.MakeNumpyDataFrame(result_dict)
result_rdf.Snapshot('tree', f'DNN_Trees/full/multi_DNN_file.root')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-6b26cdceae40> in <module>
#       3
#       4 result_dict = {key.decode("utf-8"): result_df[key].values for key in list(result_df.columns)}
# ----> 5 result_rdf = rt.RDF.MakeNumpyDataFrame(result_dict)
#       6 result_rdf.Snapshot('tree', f'DNN_Trees/full/multi_DNN_file.root')
#
# RuntimeError: Object not convertible: Dictionary entry leading_photon_pt is not convertible with AsRVec.

# %%
mc_labels = ['GluGluToHH', 'VBFToHH',
            'VHToGG', 'ttHToGG', 'VBFHToGG', 'GluGluHtoGG',
            'TTJets', 'TTGJets', 'TTGG_0Jets',
            'GJet_SmallPt', 'GJet_BigPt', 'DiPhotonJetsBox', 'DiPhotonJetsBox1B', 'DiPhotonJetsBox2B', 'QCDJets']

for i in range(len(mc_labels)):
    print(mc_labels[i])
    original_yield = np.sum(dfs_ggHH[i].loc[:, b'genweight'].values)
    samp_df = result_df[result_df[b'actual_label'] == i]
    remaining_df = samp_df[samp_df[b'predicted_label']==0]
    remaining_yield = np.sum(remaining_df.loc[:, b'genweight_scale'].values)
    print(f'Original yield: {original_yield}')
    print(f'Remaining yield: {remaining_yield}')
    print('\n')

original_bkd_yield = np.sum(full_df[full_df[b'label_num'] != 0].loc[:, b'genweight'].values)
original_sig_yield = np.sum(full_df[full_df[b'label_num'] == 0].loc[:, b'genweight'].values)
original_significance = original_sig_yield / np.sqrt(original_bkd_yield + original_sig_yield)
val_bkd = result_df[result_df[b'label_num'] != 0]
val_sig = result_df[result_df[b'label_num'] == 0]
remaining_bkd_yield = np.sum(val_bkd[val_bkd[b'predicted_label'] == 0].loc[:, b'genweight_scale'].values)
remaining_sig_yield = np.sum(val_sig[val_sig[b'predicted_label'] == 0].loc[:, b'genweight_scale'].values)
remaining_significance = remaining_sig_yield / np.sqrt(remaining_bkd_yield + remaining_sig_yield)
print(f'Original Background Yield: {original_bkd_yield}')
print(f'Original Signal Yield: {original_sig_yield}')
print(f'Original Significance: {original_significance}')
print(f'Remaining Background Yield: {remaining_bkd_yield}')
print(f'Remaining Signal Yield: {remaining_sig_yield}')
print(f'Remaining Significance: {remaining_significance}')
# Out:
# GluGluToHH
# Original yield: 2.160290479660034
# Remaining yield: 1.177638714036416
#
#
# VBFToHH
# Original yield: 0.04713541641831398
# Remaining yield: 0.007356589489655327
#
#
# VHToGG
# Original yield: 77.61676788330078
# Remaining yield: 3.2736566410947727
#
#
# ttHToGG
# Original yield: 8.006531715393066
# Remaining yield: 0.611185896269145
#
#
# VBFHToGG
# Original yield: 33.00462341308594
# Remaining yield: 0.7481544547091739
#
#
# GluGluHtoGG
# Original yield: 446.37933349609375
# Remaining yield: 7.875159320026311
#
#
# TTJets
# Original yield: 57538.75
# Remaining yield: 1410.3838172175408
#
#
# TTGJets
# Original yield: 2033.285400390625
# Remaining yield: 103.80603578044578
#
#
# TTGG_0Jets
# Original yield: 20.19515609741211
# Remaining yield: 0.7153843819598243
#
#
# GJet_SmallPt
# Original yield: 1537.787841796875
# Remaining yield: 0
#
#
# GJet_BigPt
# Original yield: 60913.47265625
# Remaining yield: 235.28799654139874
#
#
# DiPhotonJetsBox
# Original yield: 80835.21875
# Remaining yield: 340.9978357167854
#
#
# DiPhotonJetsBox1B
# Original yield: 2525.903076171875
# Remaining yield: 121.40298078665597
#
#
# DiPhotonJetsBox2B
# Original yield: 767.833251953125
# Remaining yield: 42.86216880600749
#
#
# QCDJets
# Original yield: 125386.546875
# Remaining yield: 0
#
#
# Original Background Yield: 332124.0625
# Original Signal Yield: 2.160290479660034
# Original Significance: 0.0037485260982066393
# Remaining Background Yield: 2267.9717321324374
# Remaining Signal Yield: 1.177638714036416
# Remaining Significance: 0.024721825227571183

# %%
mc_labels = ['GluGluToHH', 'VBFToHH',
            'VHToGG', 'ttHToGG', 'VBFHToGG', 'GluGluHtoGG',
            'TTJets', 'TTGJets', 'TTGG_0Jets',
            'GJet_SmallPt', 'GJet_BigPt', 'DiPhotonJetsBox', 'DiPhotonJetsBox1B', 'DiPhotonJetsBox2B', 'QCDJets']

for i in range(len(mc_labels)):
    original_mass_gg = dfs_ggHH[i].loc[:, b'diphoton_mass'].values
    original_mass_jj = dfs_ggHH[i].loc[:, b'dibjet_mass_corr'].values
    original_weight = dfs_ggHH[i].loc[:, b'genweight'].values
    samp_df = result_df[result_df[b'actual_label'] == i]
    remaining_df = samp_df[samp_df[b'predicted_label']==0]
    remaining_mass_gg = remaining_df.loc[:, b'diphoton_mass'].values
    remaining_mass_jj = remaining_df.loc[:, b'dibjet_mass_corr'].values
    remaining_weight = remaining_df.loc[:, b'genweight'].values
    
    
    bins = np.linspace(110, 140, 20)
    
    # M_gg plot
    plt.figure(figsize=(9,6))
    plt.hist(original_mass_gg, bins=bins, weights=original_weight, density=True, label = f'{mc_labels[i]} Original', color = 'blue')
    plt.hist(remaining_mass_gg, bins=bins, weights=remaining_weight, density=True, label = f'{mc_labels[i]} Remaining', color='orange', histtype='step')
    plt.xlabel('diphoton mass')
    plt.ylabel('normalized number of events')
    plt.title(f'{mc_labels[i]} Diphoton Mass Sculpting')
    plt.legend(loc='best')
    plt.savefig(fname = f'Mass_Sculpt_Plts/full/multi_gg_mass_sculpt_{mc_labels[i]}')
    plt.close()
    
    # M_jj plot
    plt.figure(figsize=(9,6))
    plt.hist(original_mass_jj, bins=bins, weights=original_weight, density=True, label = f'{mc_labels[i]} Original', color= 'blue')
    plt.hist(remaining_mass_jj, bins=bins, weights=remaining_weight, density=True, label = f'{mc_labels[i]} Remaining', color = 'orange', histtype='step')
    plt.xlabel('dibjet corrected mass')
    plt.ylabel('normalized number of events')
    plt.title(f'{mc_labels[i]} Dibjet Corrected Mass Sculpting')
    plt.legend(loc='best')
    plt.savefig(fname = f'Mass_Sculpt_Plts/full/multi_jj_mass_sculpt_{mc_labels[i]}')
    plt.close()
# Out:
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## Model Optimization

# %%
space  = [Integer(1, 5, name='n_hidden'),
          Integer(10, 128, name='first_neuron'),
          Integer(10, 128, name = 'n_neurons'),
          Real(0.01,0.9,name='dropout_rate'),
          Categorical(['relu', 'sigmoid', 'softmax']),
          Real(10**-5, 10**0, "log-uniform", name='learning_rate')
         ]

def multi_DNN(n_hidden = 1, first_neuron = 100, n_neurons = 64, dropout_rate = 0.4, activation_func = 'sigmoid', lr= 0.00002):
    model = Sequential()
    model.add(Dense(first_neuron, input_dim=len(training_vars), activation='relu'))
    model.add(Dropout(dropout_rate))
    for layer in range(n_hidden):
        model.add(Dense(n_neurons, activation = activation_func))
        model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation = 'sigmoid'))
    opt = Adam(learning_rate = lr)
    model.compile(loss=SparseCategoricalCrossentropy(), optimizer=opt, metrics=[SparseCategoricalAccuracy()])
    return model

# @use_named_args(space)
# def objective(**X):
#     print("New configuration: {}".format(X))
#     model_tmp = multi_DNN(X['n_hidden'], X['first_neuron'], X['n_neurons'], X['dropout_rate'], X['activation_func'], X['lr'])
#     print (model_tmp)
#     model_tmp.fit(X_train, Y_train, epochs=200,batch_size=64, validation_split = 0.2, 
#            callbacks=[EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')])
    
#     train_accuracy = model_tmp.evaluate(X_train, Y_train)[1]
#     print("Training Accuracy: %.2f%%" % (train_accuracy * 100.0))
    
#     accuracy = model_tmp.evaluate(X_val, Y_val)[1]
#     print("Accuracy: %.2f%%" % (accuracy * 100.0))
    
#     return -accuracy
